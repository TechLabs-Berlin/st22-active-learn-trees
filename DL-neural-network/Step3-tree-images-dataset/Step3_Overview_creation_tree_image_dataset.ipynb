# %% [markdown]
# this is a part of bigger pipeline for the project (------------ADD LINK -------------)

# %% [markdown]
# ##### --- for the Blog ----
# ## Project outline of CNN for tree identification
#
# - tree species in Berlin - Analysis by Hany (Step 0)
# a) berlin databank of trees:
# berlin_trees = ['ACER', 'AESCULUS','BETULA', 'CARPINUS', 'CORYLUS','CRATAEGUS','FRAXINUS','PLATANUS','POPULUS', 'PRUNUS','QUERCUS','ROBINIA','SORBUS','TILIA', 'ULMUS']
# b) Adding genus/family present in Austrian leave set
# 'FAGUS'
#
#
# - Identification of suitable image dataset (Step 1) (### done)
# (we face difficaties using imagenet (Explain why -----)
# We decided we will focus on the tree species in Berlin and create an image dataset downloaded via bing with a focus on leaves. We decided we will measure our success by using the Austrian leaves dataset.
# ### deployment of model used in browser (Step 2)
# - this is done , in the mid-term  (explain more ---------)
#
# --> output file/google colab with text, code, results and conclusion
# Inital Setup of softwarepipeline, deployment of model used in browser (Step 2)
# --> Integration into Web application on Trees website
# #### improving the model & Active learning (step 3, step 4)
#
# -  Downloading Images from Bing and manually sorting (Step3)
#
# (---------- rewrite-----------)
#
# Active learn via python library (Step 4)  - via superintend
# 1) species in Berlin --> image download via bing focused on LEAVES OF SPECIES
# (maybe future:) 2) large(very old and high circumference) tree vs small tree (young, saplings etc), no tree --> image download via bing
# How to measure successful improvement of model? - Austrian leaves dataset
# Decision and implentation of the “best model (Step 5)
# All of this originates from the idea to combine species and age of tree to estimate CO2 absorption.
# And DL/AI learning: implementing transfer learning and active learning
#
#
#
# (---------- rewrite ----------)
# Next steps:
# download bing images of tree species in Berlin (Step 3)
# manual labeling
# Active learning voila/python notebook (deployment? database?) (Step 4)
# CNN model (Step 5)
# How to measure sucess? Austrian leaves dataset?
# Own CNN
# Transfer learning (pre trained eg on imagenet)
# mobile net etc
# I naturalist

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as sk_metrics
import time

# %% [markdown]
# ### Trees in Berlin
# - based on a quick excel file we found 63 Genus, with futher reserch we decided to only include the most common one ( > 4000 trees)

# %%
df = pd.read_excel('https://github.com/TechLabs-Berlin/st22-active-learn-trees/blob/DL-Neural-Network-updates/DL-neural-network/Step0%20-%20quick%20berlin%20tree%20analysis/AI%20tree%20in%20berlin.xlsx?raw=true')

df = df.dropna()
df
# Out:
#       Tree type  Tot_number
# 0        Abies         177.0
# 2         ACER       88399.0
# 4     AESCULUS       20605.0
# 6    AILANTHUS         934.0
# 8        ALNUS        1048.0
# ..          ...          ...
# 116       TILIA     152227.0
# 118       TOONA          3.0
# 120       TSUGA          3.0
# 122       ULMUS       6921.0
# 124     ZELKOVA         46.0
#
# [63 rows x 2 columns]

# %%
#df['Tot_number']
### i dont know why it gives an error 
#df['Tot_number'].value_counts().plot(kind='bar',title='Number Distribution' ,label= '.')

# %%
## define tree genus -- we replaced PINUS with Fagus

berlin_trees = ['ACER leaves', 'AESCULUS leaves','BETULA leaves', 'CARPINUS leaves', 'CORYLUS leaves','CRATAEGUS leaves','FRAXINUS leaves','PLATANUS leaves','POPULUS leaves', 'PRUNUS leaves','QUERCUS leaves','ROBINIA leaves','SORBUS leaves','TILIA leaves', 'ULMUS leaves', 'Fagus leaves']

# %% [markdown]
# ## Download images from Bing image
#  to ensure better results the search is based on 2 criteria :
#
#   1- use Latin names of the trees.
#
#   2- limiting the Dataset to just tree leaves, to easily judge the results as the model intends to use Austrian leaves dataset as an external test set.

# %%
# !pip install bing-image-downloader
from bing_image_downloader import downloader
from fastai.imports import *

###

tree_types = 'acer leaves'
path = Path('trees-bing-Berlin-test12')

### Download images from Bing image

for o in berlin_trees:
  downloader.download(o, limit=50, output_dir=path, adult_filter_off=False, force_replace=False, timeout=5)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [%] Indexed 18 Images on Page 3321.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3322
#
# [%] Indexed 18 Images on Page 3322.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3323
#
# [%] Indexed 18 Images on Page 3323.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3324
#
# [%] Indexed 18 Images on Page 3324.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3325
#
# [%] Indexed 18 Images on Page 3325.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3326
#
# [%] Indexed 18 Images on Page 3326.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3327
#
# [%] Indexed 18 Images on Page 3327.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3328
#
# [%] Indexed 18 Images on Page 3328.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3329
#
# [%] Indexed 18 Images on Page 3329.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3330
#
# [%] Indexed 18 Images on Page 3330.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3331
#
# [%] Indexed 18 Images on Page 3331.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3332
#
# [%] Indexed 18 Images on Page 3332.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3333
#
# [%] Indexed 18 Images on Page 3333.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3334
#
# [%] Indexed 18 Images on Page 3334.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3335
#
# [%] Indexed 18 Images on Page 3335.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3336
#
# [%] Indexed 18 Images on Page 3336.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3337
#
# [%] Indexed 18 Images on Page 3337.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3338
#
# [%] Indexed 18 Images on Page 3338.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3339
#
# [%] Indexed 18 Images on Page 3339.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3340
#
# [%] Indexed 18 Images on Page 3340.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3341
#
# [%] Indexed 18 Images on Page 3341.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3342
#
# [%] Indexed 18 Images on Page 3342.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3343
#
# [%] Indexed 18 Images on Page 3343.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3344
#
# [%] Indexed 18 Images on Page 3344.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3345
#
# [%] Indexed 18 Images on Page 3345.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3346
#
# [%] Indexed 18 Images on Page 3346.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3347
#
# [%] Indexed 18 Images on Page 3347.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3348
#
# [%] Indexed 18 Images on Page 3348.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3349
#
# [%] Indexed 18 Images on Page 3349.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3350
#
# [%] Indexed 18 Images on Page 3350.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3351
#
# [%] Indexed 18 Images on Page 3351.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3352
#
# [%] Indexed 18 Images on Page 3352.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3353
#
# [%] Indexed 18 Images on Page 3353.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3354
#
# [%] Indexed 18 Images on Page 3354.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3355
#
# [%] Indexed 18 Images on Page 3355.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3356
#
# [%] Indexed 18 Images on Page 3356.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3357
#
# [%] Indexed 18 Images on Page 3357.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3358
#
# [%] Indexed 18 Images on Page 3358.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3359
#
# [%] Indexed 18 Images on Page 3359.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3360
#
# [%] Indexed 18 Images on Page 3360.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3361
#
# [%] Indexed 18 Images on Page 3361.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3362
#
# [%] Indexed 18 Images on Page 3362.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3363
#
# [%] Indexed 18 Images on Page 3363.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3364
#
# [%] Indexed 18 Images on Page 3364.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3365
#
# [%] Indexed 18 Images on Page 3365.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3366
#
# [%] Indexed 18 Images on Page 3366.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3367
#
# [%] Indexed 18 Images on Page 3367.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3368
#
# [%] Indexed 18 Images on Page 3368.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3369
#
# [%] Indexed 18 Images on Page 3369.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3370
#
# [%] Indexed 18 Images on Page 3370.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3371
#
# [%] Indexed 18 Images on Page 3371.
#
# ===============================================
#
#
#
# [!!]Indexing page: 

#
# ===============================================
#
#
#
# [!!]Indexing page: 3873
#
# [%] Indexed 18 Images on Page 3873.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3874
#
# [%] Indexed 18 Images on Page 3874.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3875
#
# [%] Indexed 18 Images on Page 3875.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3876
#
# [%] Indexed 18 Images on Page 3876.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3877
#
# [%] Indexed 18 Images on Page 3877.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3878
#
# [%] Indexed 18 Images on Page 3878.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3879
#
# [%] Indexed 18 Images on Page 3879.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3880
#
# [%] Indexed 18 Images on Page 3880.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3881
#
# [%] Indexed 18 Images on Page 3881.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3882
#
# [%] Indexed 18 Images on Page 3882.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3883
#
# [%] Indexed 18 Images on Page 3883.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3884
#
# [%] Indexed 18 Images on Page 3884.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3885
#
# [%] Indexed 18 Images on Page 3885.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3886
#
# [%] Indexed 18 Images on Page 3886.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3887
#
# [%] Indexed 18 Images on Page 3887.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3888
#
# [%] Indexed 18 Images on Page 3888.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3889
#
# [%] Indexed 18 Images on Page 3889.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3890
#
# [%] Indexed 18 Images on Page 3890.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3891
#
# [%] Indexed 18 Images on Page 3891.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3892
#
# [%] Indexed 18 Images on Page 3892.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3893
#
# [%] Indexed 18 Images on Page 3893.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3894
#
# [%] Indexed 18 Images on Page 3894.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3895
#
# [%] Indexed 18 Images on Page 3895.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3896
#
# [%] Indexed 18 Images on Page 3896.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3897
#
# [%] Indexed 18 Images on Page 3897.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3898
#
# [%] Indexed 18 Images on Page 3898.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3899
#
# [%] Indexed 18 Images on Page 3899.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3900
#
# [%] Indexed 18 Images on Page 3900.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3901
#
# [%] Indexed 18 Images on Page 3901.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3902
#
# [%] Indexed 18 Images on Page 3902.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3903
#
# [%] Indexed 18 Images on Page 3903.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3904
#
# [%] Indexed 18 Images on Page 3904.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3905
#
# [%] Indexed 18 Images on Page 3905.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3906
#
# [%] Indexed 18 Images on Page 3906.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3907
#
# [%] Indexed 18 Images on Page 3907.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3908
#
# [%] Indexed 18 Images on Page 3908.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3909
#
# [%] Indexed 18 Images on Page 3909.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3910
#
# [%] Indexed 18 Images on Page 3910.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3911
#
# [%] Indexed 18 Images on Page 3911.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3912
#
# [%] Indexed 18 Images on Page 3912.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3913
#
# [%] Indexed 18 Images on Page 3913.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3914
#
# [%] Indexed 18 Images on Page 3914.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3915
#
# [%] Indexed 18 Images on Page 3915.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3916
#
# [%] Indexed 18 Images on Page 3916.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3917
#
# [%] Indexed 18 Images on Page 3917.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3918
#
# [%] Indexed 18 Images on Page 3918.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3919
#
# [%] Indexed 18 Images on Page 3919.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3920
#
# [%] Indexed 18 Images on Page 3920.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3921
#
# [%] Indexed 18 Images on Page 3921.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3922
#
# [%] Indexed 18 Images on Page 3922.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3923
#
# [%] Indexed 18 Images on Page 3923.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3924
#
# [%] Indexed 18 Images on Page 3924.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3925
#
# [%] Indexed 18 Images on Page 3925.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3926
#
# [%] Indexed 18 Images on Page 3926.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3927
#
# [%] Indexed 18 Images on Page 3927.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3928
#
# [%] Indexed 18 Images on Page 3928.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3929
#
# [%] Indexed 18 Images on Page 3929.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3930
#
# [%] Indexed 18 Images on Page 3930.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3931
#
# [%] Indexed 18 Images on Page 3931.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3932
#
# [%] Indexed 18 Images on Page 3932.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3933
#
# [%] Indexed 18 Images on Page 3933.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3934
#
# [%] Indexed 18 Images on Page 3934.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3935
#
# [%] Indexed 18 Images on Page 3935.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3936
#
# [%] Indexed 18 Images on Page 3936.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3937
#
# [%] Indexed 18 Images on Page 3937.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3938
#
# [%] Indexed 18 Images on Page 3938.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3939
#
# [%] Indexed 16 Images on Page 3939.
#
# ===============================================
#
# [%] Downloading Image #40 from https://i.pinimg.com/736x/00/c4/d3/00c4d384f4feccd315b4da44f4ccf0ae--fagus-pr.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #41 from http://www.jerseyyards.org/wp/wp-content/uploads/2014/09/fagus-grandifolia-d.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #42 from https://fthmb.tqn.com/_d81x41xqlIyj8vmHXKLq4V74JQ=/2172x1381/filters:fill(auto,1)/Americanbeechleaves-GettyImages-81622905-5a1b6f40e258f8003ba31fec.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #43 from https://daynaa2000.files.wordpress.com/2013/06/fagus-leaves.jpg?w=1350
# [Error]Invalid image, not saving https://daynaa2000.files.wordpress.com/2013/06/fagus-leaves.jpg?w=1350
#
# [!] Issue getting: https://daynaa2000.files.wordpress.com/2013/06/fagus-leaves.jpg?w=1350
# [!] Error:: Invalid image, not saving https://daynaa2000.files.wordpress.com/2013/06/fagus-leaves.jpg?w=1350
#
# [%] Downloading Image #43 from https://img.plantsam.com/wp-content/uploads/2015/06/Fagus-sylvatica.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #44 from https://daisyshop.co.uk/WebRoot/Store15/Shops/48a30d8e-73da-4cb9-be3e-65bc79cf7753/5C48/6121/D61A/E6D1/1438/0A48/3535/16EB/fagus_leaves_seconds.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #45 from https://s-media-cache-ak0.pinimg.com/736x/70/bd/89/70bd89e547d78a4ef2d46f58824b0823.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #46 from https://treescanadensis.ca/wp-content/uploads/2018/12/Beech-Bark-Disease.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #47 from http://2.bp.blogspot.com/-B7kZFL8rPNo/T3nWMtp9unI/AAAAAAAACo4/QPqyerUyN3g/s1600/3.22_Fagus_grandifolia_2.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #48 from https://www.thetreecenter.com/c/uploads/columnar-purple-beech-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #49 from http://homepage.tinet.ie/~portlawns/images/BeechFruit.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #50 from https://www.gardenia.net/storage/app/public/uploads/images/shutterstock_787694509Optimized.jpg
# [!] Issue getting: https://www.gardenia.net/storage/app/public/uploads/images/shutterstock_787694509Optimized.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #50 from https://cdn.britannica.com/26/152026-050-41D137DE/Sunshine-leaves-beech-tree.jpg
# [Error]Invalid image, not saving https://cdn.britannica.com/26/152026-050-41D137DE/Sunshine-leaves-beech-tree.jpg
#
# [!] Issue getting: https://cdn.britannica.com/26/152026-050-41D137DE/Sunshine-leaves-beech-tree.jpg
# [!] Error:: Invalid image, not saving https://cdn.britannica.com/26/152026-050-41D137DE/Sunshine-leaves-beech-tree.jpg
#
# [%] Downloading Image #50 from https://florafinder.org/LargePhotos/DE/Fagus_grandifolia-3E4443C41E.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 50 images.

# %% [markdown]
# Saving the files

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-12-4996ee3d8d09> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     107       force_remount=force_remount,
#     108       timeout_ms=timeout_ms,
# --> 109       ephemeral=True)
#     110
#     111
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral)
#     122   if ephemeral:
#     123     _message.blocking_request(
# --> 124         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     125
#     126   mountpoint = _os.path.expanduser(mountpoint)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     173   request_id = send_request(
#     174       request_type, request, parent=parent, expect_reply=True)
# --> 175   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: Error: credential propagation was unsuccessful

# %% [markdown]
# tree categories (part of step 4)

# %%
# berlin_Baum_typ= ['Ahorn', 'Kastanie ','Birke ', 'Hainbuche ', 'Hasel ','Weißdorn ','Esche ','Platane ','Pappel ', 'Lorbeer ','Eiche ','Robine ','Eberesche ','Linde ', 'Ulme ', 'Rotbuche ']
